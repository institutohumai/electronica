# %% [markdown]
# # Pautas generales
# Para sacarle el maximo a los siguientes ejercicios asegurate de:
# - Usar la libreria `requests`, teniendo en cuenta la verificacion de los codigos de estado. Si llegas a usar parametros de consulta recuerda no colocarlos en la URL si no como un diccionario que envias como parametro.
# - Ademas de usar Python usar Postman para entender como usar este tipo de aplicaciones.

# %% [markdown]
# # 1er ejercicio: Conteo de calorias

# %% [markdown]
# **Contexto:** Un nutricionista te ha contratado para desarrollar una aplicación que le permita comunicar a sus pacientes información nutricional sobre las dietas que les prescribe. Una parte importante de sus dietas incluye ensaladas de frutas, y desea que los pacientes puedan ver fácilmente el contenido calórico de estas ensaladas.
#
# **Objetivo:** Tu tarea es desarrollar una funcion que reciba una lista de nombres de frutas que componen una ensalada y, utilizando la [API sobre informacion de frutas](https://www.fruityvice.com/):
#
# ```
# https://www.fruityvice.com/api/fruit/{nombre-de-la-fruta-en-ingles}
# ```
#
#  calcule y muestre la suma total de calorías de la ensalada (como referencia se colocan los nombres en ingles que necesitan usar en la API):
#
# | Fruta          | Cantidad        |Nombre a usar en la API |
# |----------------|-----------------|------------------------|
# | Manzana        | 3               |apple|
# | Bananas        | 2               |banana|
# | Naranja        | 3               |orange|
# | Fresa          | 6               |strawberry|
# | Pera           | 2               |pear|
# | Durazno        | 1               |peach|
# | Piña           | 1               |pineapple|
#
#
# Recuerda que calorias en ingles se dice "calories".

# %%
# escribe el codigo aqui

# %% [markdown]
# # 2do ejercicio: Aprendiendo a leer Documentacion de una API.

# %% [markdown]
# Lee la documentacion y selecciona los endpoints correctos para resolver los siguientes problemas a traves del uso de la API:
#
# - El resultado de 5 elevado al exponente 7
# - El precio resultante de descontar 35% a 345912
# - Cuantas hectareas son 32.57 km cuadrados
#
#
#
# [Docs de API para calculos varios](https://fastapi-calculadora.onrender.com/docs#/)

# %%
# escribe tu codigo aqui

# %% [markdown]
# # 3er ejercicio: Usando una API con token.

# %% [markdown]
# Para poder realizar este ejercicio necesitaras crearte una cuenta dentro de https://app.exchangerate-api.com/sign-up, luego podras ver obtener tu API key (token) en el Dashboard de tu cuenta.
#
#
# Se vera asi (esto es solo un ejemplo, tu token sera un codigo distinto):

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Copia el codigo en negrita y colocalo en la variable `api_key` en la celda de abajo.

# %% [markdown]
# El objetivo de este ejercicio es terminar la logica de la funcion llamada `calcular_equivalencias_desde_dolares` que recibe un monto en dolares y retorne sus montos equivalentes en el resto de las unidades monetarias mostradas en la siguiente tabla:
#
# | Moneda         | Codigo        |
# |----------------|-----------------|
# | Dolar Estadounidense        | USD               |
# | Dolar Australiano        | AUD               |
# | Dolar Neozelandes        | NZD               |
# | Libras Esterlinas          | GBP               |
# | Euro          | EUR               |
# | Pesos Argentinos        | ARS               |
# | Pesos Mexicanos           | MXN               |
#
# Para realizar esta tarea tendras que usar este endpoint:
#
# ```
# GET https://v6.exchangerate-api.com/v6/{TU-API-KEY}/latest/USD
# ```
#
# La respuesta exitosa tendra este formato:
#
#
# ```
# {
# 	"result": "success",
# 	"documentation": "https://www.exchangerate-api.com/docs",
# 	"terms_of_use": "https://www.exchangerate-api.com/terms",
# 	"time_last_update_unix": 1585267200,
# 	"time_last_update_utc": "Fri, 27 Mar 2020 00:00:00 +0000",
# 	"time_next_update_unix": 1585353700,
# 	"time_next_update_utc": "Sat, 28 Mar 2020 00:00:00 +0000",
# 	"base_code": "USD",
# 	"conversion_rates": {
# 		"USD": 1,
# 		"AUD": 1.4817,
# 		"BGN": 1.7741,
# 		"CAD": 1.3168,
# 		"CHF": 0.9774,
# 		"CNY": 6.9454,
# 		"EGP": 15.7361,
# 		"EUR": 0.9013,
# 		"GBP": 0.7679,
# 		"...": 7.8536,
# 		"...": 1.3127,
# 		"...": 7.4722, etc. etc.
# 	}
# }
#
# ```
#
# El diccionario bajo la llave de `"conversion_rates"` contiene las distintas tasas de conversion de dolares hacia la moneda objetivo, en donde cada una de las llaves son los codigos de la monedas.
#
#
# ---
# > ⚠ ***CUIDADO***
# >
# > *Recuerda que es una cuenta gratuita, con esta API solo puedes realizar 1500 peticiones por mes. Trata de resolver el ejercicio sin usar todas las peticiones.*
# ---

# %%
def calcular_equivalencias_desde_dolares(monto_dolares: float):
    api_key = ""  # coloca aqui tu api key generada al crearte una cuenta gratuita

    # coloca aqui el resto de la logica.

# %% [markdown]
# # 4to ejercicio: Conversor de Pesos Argentinos a Dolares

# %% [markdown]
# Usa la api https://dolarapi.com/docs/ para crear una funcion que reciba una cantidad de pesos y la transforme en dolares usando el dolar "blue".

# %%
def convertir_pesos_a_dolar_blue(cantidad_pesos: float) -> float:
    # tu codigo aqui
    ...
